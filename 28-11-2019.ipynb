# %%
import numpy as np
import pandas as pd

# %%
x=pd.read_excel('Energy Indicators.xls')
x
# Out:
#      Unnamed: 0                                         Unnamed: 1  \
# 0           NaN                                                NaN
# 1           NaN                                                NaN
# 2           NaN                                                NaN
# 3           NaN                                                NaN
# 4           NaN                                                NaN
# 5           NaN                                                NaN
# 6           NaN                                                NaN
# 7           NaN                                                NaN
# 8           NaN                                                NaN
# 9           NaN                                                NaN
# 10          NaN                                                NaN
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# ...

# %%
x.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5'],
#       dtype='object')

# %%
x=x[x.columns[2:]]
x.head()
# Out:
#                                           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                   Environmental Indicators: Energy        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2  Energy Supply and Renewable Electricity Produc...        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                                NaN        NaN        NaN
#
#                    Unnamed: 5
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4  Last update: December 2015

# %%
x.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
x.columns
# Out:
# Index(['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable'], dtype='object')

# %%
x=x[17:]
x
# Out:
#                                                Country Energy Supply  \
# 17                                         Afghanistan           321
# 18                                             Albania           102
# 19                                             Algeria          1959
# 20                                      American Samoa           ...
# 21                                             Andorra             9
# 22                                              Angola           642
# 23                                            Anguilla             2
# 24                                 Antigua and Barbuda             8
# 25                                           Argentina          3378
# 26                                             Armenia           143
# 27                                               Aruba            12
# 28                                          Australia1          5386
# 29                                             Austria          1391
# ...

# %%
x=x[:227]
x
# Out:
#                                                Country Energy Supply  \
# 17                                         Afghanistan           321
# 18                                             Albania           102
# 19                                             Algeria          1959
# 20                                      American Samoa           ...
# 21                                             Andorra             9
# 22                                              Angola           642
# 23                                            Anguilla             2
# 24                                 Antigua and Barbuda             8
# 25                                           Argentina          3378
# 26                                             Armenia           143
# 27                                               Aruba            12
# 28                                          Australia1          5386
# 29                                             Austria          1391
# ...

# %%
x[x=='...']=np.nan
x
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                                                Country Energy Supply  \
# 17                                         Afghanistan           321
# 18                                             Albania           102
# 19                                             Algeria          1959
# 20                                      American Samoa           NaN
# 21                                             Andorra             9
# 22                                              Angola           642
# 23                                            Anguilla             2
# ...

# %%
x['Energy Supply']=x['Energy Supply']*1000000
x['Energy Supply']
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 17       321000000000000
# 18       102000000000000
# 19      1959000000000000
# 20                   NaN
# 21         9000000000000
# 22       642000000000000
# 23         2000000000000
# 24         8000000000000
# 25      3378000000000000
# 26       143000000000000
# 27        12000000000000
# 28      5386000000000000
# 29      1391000000000000
# 30       567000000000000
# 31        45000000000000
# 32       574000000000000
# 33      1625000000000000
# 34        19000000000000
# 35      1142000000000000
# 36      2338000000000000
# 37        13000000000000
# 38       170000000000000
# ...

# %%
x['Energy Supply'].head()
# Out:
# 17     321000000000000
# 18     102000000000000
# 19    1959000000000000
# 20                 NaN
# 21       9000000000000
# Name: Energy Supply, dtype: object
