# %% [markdown]
# ### Global Sales Data

# %%
# import required packages
import pandas as pd
df=pd.read_csv('market.csv')
df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
# check the shape
df.shape
# Out:
# (8399, 10)

# %%
# Observe the top 4 rows
df.head(4)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818   136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818    42.27      0.01              13
# 2  Ord_5446   Prod_4  SHP_7610  Cust_1818  4701.69      0.00              26
# 3  Ord_5456   Prod_6  SHP_7625  Cust_1818  2337.89      0.09              43
#
#     Profit  Shipping_Cost  Product_Base_Margin
# 0   -30.51           3.60                 0.56
# 1     4.56           0.93                 0.54
# 2  1148.90           2.50                 0.59
# 3   729.34          14.30                 0.37

# %%
# observe the last two rows
df.tail(2)
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 8397  Ord_5348  Prod_15  SHP_7469  Cust_1798  3872.87      0.03
# 8398  Ord_5459   Prod_6  SHP_7628  Cust_1798   603.69      0.00
#
#       Order_Quantity  Profit  Shipping_Cost  Product_Base_Margin
# 8397              23  565.34          30.00                 0.62
# 8398              47  131.39           4.86                 0.38

# %%
# observe 5 rows randomly
df.sample(5)
# Out:
#         Ord_id Prod_id   Ship_id    Cust_id    Sales  Discount  \
# 3029  Ord_4876  Prod_5  SHP_6804  Cust_1673  4814.12      0.03
# 3382  Ord_5140  Prod_8  SHP_7181  Cust_1744   827.27      0.05
# 7065   Ord_832  Prod_3  SHP_1140   Cust_195  4722.83      0.01
# 7564  Ord_2748  Prod_8  SHP_3770  Cust_1015  1455.49      0.07
# 2314  Ord_3916  Prod_6  SHP_5437  Cust_1337   710.33      0.09
#
#       Order_Quantity   Profit  Shipping_Cost  Product_Base_Margin
# 3029              46   855.14          21.26                 0.59
# 3382              40  -170.87           6.50                 0.78
# 7065              27  1749.78          19.99                 0.40
# 7564               5  -807.59           7.18                 0.48
# 2314              38    62.53           9.03                 0.37

# %%
# check the column names
df.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin'],
#       dtype='object')

# %%
# check the row indices
df.index
# Out:
# RangeIndex(start=0, stop=8399, step=1)

# %%
# Check for the missing values if there are any print the count
df.isnull().sum()
# column wise
# Out:
# Ord_id                  0
# Prod_id                 0
# Ship_id                 0
# Cust_id                 0
# Sales                   0
# Discount                0
# Order_Quantity          0
# Profit                  0
# Shipping_Cost           0
# Product_Base_Margin    63
# dtype: int64

# %%
# Check the data types of column
df.dtypes
# Out:
# Ord_id                  object
# Prod_id                 object
# Ship_id                 object
# Cust_id                 object
# Sales                  float64
# Discount               float64
# Order_Quantity           int64
# Profit                 float64
# Shipping_Cost          float64
# Product_Base_Margin    float64
# dtype: object

# %%
# Calculate the no of columns for each type
df.dtypes.value_counts()
# Out:
# float64    5
# object     4
# int64      1
# dtype: int64

# %%
# What are the min and max values in ecah column
df.describe().loc[['min','max']]
# Out:
#         Sales  Discount  Order_Quantity    Profit  Shipping_Cost  \
# min      2.24      0.00             1.0 -14140.70           0.49
# max  89061.05      0.25            50.0  27220.69         164.73
#
#      Product_Base_Margin
# min                 0.35
# max                 0.85

# %%
df.describe().iloc[[3,7]]
# Out:
#         Sales  Discount  Order_Quantity    Profit  Shipping_Cost  \
# min      2.24      0.00             1.0 -14140.70           0.49
# max  89061.05      0.25            50.0  27220.69         164.73
#
#      Product_Base_Margin
# min                 0.35
# max                 0.85

# %%
# What are the min and max values in ecah column
df.columns.max()
# Out:
# 'Shipping_Cost'

# %%
df.columns.min()
# Out:
# 'Cust_id'

# %%
df.describe()
# Out:
#               Sales     Discount  Order_Quantity        Profit  Shipping_Cost  \
# count   8399.000000  8399.000000     8399.000000   8399.000000    8399.000000
# mean    1775.878179     0.049671       25.571735    181.184424      12.838557
# std     3585.050525     0.031823       14.481071   1196.653371      17.264052
# min        2.240000     0.000000        1.000000 -14140.700000       0.490000
# 25%      143.195000     0.020000       13.000000    -83.315000       3.300000
# 50%      449.420000     0.050000       26.000000     -1.500000       6.070000
# 75%     1709.320000     0.080000       38.000000    162.750000      13.990000
# max    89061.050000     0.250000       50.000000  27220.690000     164.730000
#
#        Product_Base_Margin
# count          8336.000000
# mean              0.512513
# std               0.135589
# min               0.350000
# 25%               0.380000
# 50%               0.520000
# 75%               0.590000
# max               0.850000

# %%
# categorical column names
cat_col=df.columns[df.dtypes==object]
cat_col
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id'], dtype='object')

# %%
df[cat_col].nunique()
# Out:
# Ord_id     5506
# Prod_id      17
# Ship_id    7701
# Cust_id    1832
# dtype: int64

# %%
# Calculate the no of unique values in each categorical column
df.nunique()
# Out:
# Ord_id                 5506
# Prod_id                  17
# Ship_id                7701
# Cust_id                1832
# Sales                  8153
# Discount                 16
# Order_Quantity           50
# Profit                 7807
# Shipping_Cost           652
# Product_Base_Margin      51
# dtype: int64

# %%
# Calculate category frequecies for each value in the categorical 
for i in cat_col:
    print(df[i].value_counts())
# Out:
# Ord_542     6
# Ord_2506    6
# Ord_1053    5
# Ord_1931    5
# Ord_1581    5
# Ord_5186    5
# Ord_1234    5
# Ord_1980    5
# Ord_996     5
# Ord_845     5
# Ord_1664    5
# Ord_1639    5
# Ord_4946    5
# Ord_2894    5
# Ord_4025    5
# Ord_2970    5
# Ord_2370    5
# Ord_1846    5
# Ord_56      5
# Ord_1791    5
# Ord_2164    5
# Ord_5378    4
# Ord_1020    4
# Ord_4704    4
# Ord_694     4
# Ord_1660    4
# Ord_615     4
# Ord_5428    4
# Ord_4241    4
# Ord_4606    4
#            ..
# Ord_695     1
# Ord_1429    1
# Ord_2507    1
# Ord_356     1
# Ord_2684    1
# Ord_2566    1
# Ord_244     1
# Ord_1008    1
# Ord_5374    1
# Ord_2483    1
# Ord_3897    1
# Ord_1778    1
# Ord_5251    1
# Ord_2195    1
# Ord_2159    1
# Ord_601     1
# Ord_3256    1
# Ord_1245    1
# Ord_4755    1
# Ord_5407    1
# Ord_553     1
# Ord_1226    1
# Ord_3797    1
# Ord_2107    1
# Ord_5256    1
# Ord_4781    1
# Ord_278     1
# Ord_2940    1
# Ord_3553    1
# Ord_801     1
# ...

# %%
# Calculate the no of columns for each type
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8399 entries, 0 to 8398
# Data columns (total 10 columns):
# Ord_id                 8399 non-null object
# Prod_id                8399 non-null object
# Ship_id                8399 non-null object
# Cust_id                8399 non-null object
# Sales                  8399 non-null float64
# Discount               8399 non-null float64
# Order_Quantity         8399 non-null int64
# Profit                 8399 non-null float64
# Shipping_Cost          8399 non-null float64
# Product_Base_Margin    8336 non-null float64
# dtypes: float64(5), int64(1), object(4)
# memory usage: 656.2+ KB

# %% [markdown]
# #### Read the remaing four csv files.Store them in cust_df,prod_df,ship_df,order_df

# %%
import pandas as pd
cust_df=pd.read_csv('customer.csv')
cust_df
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1           BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER     Cust_2
# 2          CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE     Cust_3
# 3         CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER     Cust_4
# 4           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# 5         MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE     Cust_6
# 6        DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_7
# 7        NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_8
# 8            CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_9
# 9          CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_10
# 10      ALLEN ROSENBLATT  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_11
# 11       SYLVIA FOULSTON  NUNAVUT  NUNAVUT      HOME OFFICE    Cust_12
# ...

# %%
cust_df.head(5)
# Out:
#         Customer_Name Province   Region Customer_Segment Cust_id
# 0  MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_1
# 1        BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER  Cust_2
# 2       CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE  Cust_3
# 3      CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER  Cust_4
# 4        CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE  Cust_5

# %%
cust_df
# Out:
#            Customer_Name Province   Region Customer_Segment    Cust_id
# 0     MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS     Cust_1
# 1           BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER     Cust_2
# 2          CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE     Cust_3
# 3         CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER     Cust_4
# 4           CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE     Cust_5
# 5         MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE     Cust_6
# 6        DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_7
# 7        NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_8
# 8            CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE     Cust_9
# 9          CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_10
# 10      ALLEN ROSENBLATT  NUNAVUT  NUNAVUT   SMALL BUSINESS    Cust_11
# 11       SYLVIA FOULSTON  NUNAVUT  NUNAVUT      HOME OFFICE    Cust_12
# ...

# %%
print(cust_df.shape)
print(df.Cust_id.nunique())
# Out:
# (1832, 5)
# 1832

# %%
order_df=pd.read_csv('orders.csv')
order_df
# Out:
#       Order_ID  Order_Date Order_Priority    Ord_id
# 0            3  13-10-2010            LOW     Ord_1
# 1          293  01-10-2012           HIGH     Ord_2
# 2          483  10-07-2011           HIGH     Ord_3
# 3          515  28-08-2010  NOT SPECIFIED     Ord_4
# 4          613  17-06-2011           HIGH     Ord_5
# 5          643  24-03-2011           HIGH     Ord_6
# 6          678  26-02-2010            LOW     Ord_7
# 7          807  23-11-2010         MEDIUM     Ord_8
# 8          868  08-06-2012  NOT SPECIFIED     Ord_9
# 9          933  04-08-2012  NOT SPECIFIED    Ord_10
# 10         995  30-05-2011         MEDIUM    Ord_11
# 11         998  25-11-2009  NOT SPECIFIED    Ord_12
# 12        1154  14-02-2012       CRITICAL    Ord_13
# 13        1344  15-04-2012            LOW    Ord_14
# 14        1412  12-03-2010  NOT SPECIFIED    Ord_15
# 15        1539  09-03-2011            LOW    Ord_16
# 16        1540  04-08-2012           HIGH    Ord_17
# ...

# %%
df.Ord_id[:5]
# Out:
# 0    Ord_5446
# 1    Ord_5406
# 2    Ord_5446
# 3    Ord_5456
# 4    Ord_5485
# Name: Ord_id, dtype: object

# %%
order_df.head(5)
# Out:
#    Order_ID  Order_Date Order_Priority Ord_id
# 0         3  13-10-2010            LOW  Ord_1
# 1       293  01-10-2012           HIGH  Ord_2
# 2       483  10-07-2011           HIGH  Ord_3
# 3       515  28-08-2010  NOT SPECIFIED  Ord_4
# 4       613  17-06-2011           HIGH  Ord_5

# %%
pro_df=pd.read_csv('product.csv')
pro_df
# Out:
#    Product_Category            Product_Sub_Category  Prod_id
# 0   OFFICE SUPPLIES          STORAGE & ORGANIZATION   Prod_1
# 1   OFFICE SUPPLIES                      APPLIANCES   Prod_2
# 2   OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES   Prod_3
# 3        TECHNOLOGY    TELEPHONES AND COMMUNICATION   Prod_4
# 4         FURNITURE              OFFICE FURNISHINGS   Prod_5
# 5   OFFICE SUPPLIES                           PAPER   Prod_6
# 6   OFFICE SUPPLIES                    RUBBER BANDS   Prod_7
# 7        TECHNOLOGY            COMPUTER PERIPHERALS   Prod_8
# 8   OFFICE SUPPLIES                       ENVELOPES   Prod_9
# 9         FURNITURE                       BOOKCASES  Prod_10
# 10        FURNITURE                          TABLES  Prod_11
# 11  OFFICE SUPPLIES                          LABELS  Prod_12
# 12  OFFICE SUPPLIES             PENS & ART SUPPLIES  Prod_13
# 13       TECHNOLOGY                 COPIERS AND FAX  Prod_14
# ...

# %%
pro_df.head(5)
# Out:
#   Product_Category            Product_Sub_Category Prod_id
# 0  OFFICE SUPPLIES          STORAGE & ORGANIZATION  Prod_1
# 1  OFFICE SUPPLIES                      APPLIANCES  Prod_2
# 2  OFFICE SUPPLIES  BINDERS AND BINDER ACCESSORIES  Prod_3
# 3       TECHNOLOGY    TELEPHONES AND COMMUNICATION  Prod_4
# 4        FURNITURE              OFFICE FURNISHINGS  Prod_5

# %%
df1=pd.merge(df,cust_df)
df1
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id       Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.8100      0.01
# 1     Ord_5406  Prod_13  SHP_7549  Cust_1818     42.2700      0.01
# 2     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.6900      0.00
# 3     Ord_5456   Prod_6  SHP_7625  Cust_1818   2337.8900      0.09
# 4     Ord_5485  Prod_17  SHP_7664  Cust_1818   4233.1500      0.08
# 5     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.0200      0.03
# 6       Ord_31  Prod_12    SHP_41    Cust_26     14.7600      0.01
# 7     Ord_4725   Prod_4  SHP_6593  Cust_1641   3410.1575      0.10
# 8     Ord_4725  Prod_13  SHP_6593  Cust_1641    162.0000      0.01
# 9     Ord_4725   Prod_6  SHP_6593  Cust_1641     57.2200      0.07
# 10    Ord_4743   Prod_2  SHP_6615  Cust_1641   4072.0100      0.01
# 11    Ord_1925   Prod_6  SHP_2637   Cust_708    465.9000      0.05
# 12    Ord_2978  Prod_16  SHP_4112  Cust_1088    305.0500      0.04
# ...

# %%
df2=pd.merge(df1,pro_df)
df2
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 5     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 6     Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 7     Ord_4506  Prod_16  SHP_6273  Cust_1544     92.02      0.07
# 8     Ord_4080  Prod_16  SHP_5688  Cust_1388    666.40      0.00
# 9     Ord_1551  Prod_16  SHP_2145   Cust_531    184.77      0.00
# 10    Ord_1579  Prod_16  SHP_2178   Cust_566    139.37      0.04
# 11    Ord_1429  Prod_16  SHP_1976   Cust_510    539.06      0.05
# 12    Ord_2471  Prod_16  SHP_3386   Cust_965     90.93      0.05
# ...

# %%
ship_df=pd.read_csv('shipping.csv')
ship_df
# Out:
#       Order_ID       Ship_Mode   Ship_Date   Ship_id
# 0            3     REGULAR AIR  20-10-2010     SHP_1
# 1          293  DELIVERY TRUCK  02-10-2012     SHP_2
# 2          293     REGULAR AIR  03-10-2012     SHP_3
# 3          483     REGULAR AIR  12-07-2011     SHP_4
# 4          515     REGULAR AIR  30-08-2010     SHP_5
# 5          613     REGULAR AIR  17-06-2011     SHP_6
# 6          613     REGULAR AIR  18-06-2011     SHP_7
# 7          643     EXPRESS AIR  25-03-2011     SHP_8
# 8          678     REGULAR AIR  26-02-2010     SHP_9
# 9          807     REGULAR AIR  24-11-2010    SHP_10
# 10         868     REGULAR AIR  09-06-2012    SHP_11
# 11         868     REGULAR AIR  10-06-2012    SHP_12
# 12         933     REGULAR AIR  04-08-2012    SHP_13
# 13         995     REGULAR AIR  31-05-2011    SHP_14
# 14         998     REGULAR AIR  26-11-2009    SHP_15
# 15        1154  DELIVERY TRUCK  16-02-2012    SHP_16
# 16        1154     REGULAR AIR  16-02-2012    SHP_17
# ...

# %%
ship_df.head(5)
# Out:
#    Order_ID       Ship_Mode   Ship_Date Ship_id
# 0         3     REGULAR AIR  20-10-2010   SHP_1
# 1       293  DELIVERY TRUCK  02-10-2012   SHP_2
# 2       293     REGULAR AIR  03-10-2012   SHP_3
# 3       483     REGULAR AIR  12-07-2011   SHP_4
# 4       515     REGULAR AIR  30-08-2010   SHP_5

# %%
df3=pd.merge(df2,ship_df)
df3
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 5     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 6     Ord_4796   Prod_6  SHP_6686  Cust_1659    122.09      0.04
# 7     Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 8     Ord_1854   Prod_6  SHP_2548   Cust_622    817.53      0.03
# 9     Ord_1854  Prod_17  SHP_2548   Cust_564     25.96      0.06
# 10    Ord_4506  Prod_16  SHP_6273  Cust_1544     92.02      0.07
# 11    Ord_4080  Prod_16  SHP_5688  Cust_1388    666.40      0.00
# 12    Ord_1551  Prod_16  SHP_2145   Cust_531    184.77      0.00
# ...

# %%
master_df=pd.merge(df3,order_df)

# %%
master_df
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_5446   Prod_4  SHP_7610  Cust_1818   4701.69      0.00
# 2     Ord_5446   Prod_6  SHP_7608  Cust_1818    164.02      0.03
# 3     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 4     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 5     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 6     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 7     Ord_4143   Prod_6  SHP_5770  Cust_1417    901.32      0.10
# 8     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 9     Ord_4796   Prod_6  SHP_6686  Cust_1659    122.09      0.04
# 10    Ord_4796  Prod_13  SHP_6687  Cust_1659    150.06      0.02
# 11    Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 12    Ord_1854   Prod_6  SHP_2548   Cust_622    817.53      0.03
# ...

# %%
####1
df1=pd.merge(df,cust_df,on='Cust_id')
df1.columns
# Out:
# Index(['Ord_id', 'Prod_id', 'Ship_id', 'Cust_id', 'Sales', 'Discount',
#        'Order_Quantity', 'Profit', 'Shipping_Cost', 'Product_Base_Margin',
#        'Customer_Name', 'Province', 'Region', 'Customer_Segment'],
#       dtype='object')

# %%
df1.head(2)
# Out:
#      Ord_id  Prod_id   Ship_id    Cust_id   Sales  Discount  Order_Quantity  \
# 0  Ord_5446  Prod_16  SHP_7609  Cust_1818  136.81      0.01              23
# 1  Ord_5406  Prod_13  SHP_7549  Cust_1818   42.27      0.01              13
#
#    Profit  Shipping_Cost  Product_Base_Margin  Customer_Name Province Region  \
# 0  -30.51           3.60                 0.56  AARON BERGMAN  ALBERTA   WEST
# 1    4.56           0.93                 0.54  AARON BERGMAN  ALBERTA   WEST
#
#   Customer_Segment
# 0        CORPORATE
# 1        CORPORATE

# %%
#### 2
df2=pd.merge(df1,pro_df,on='Prod_id')
df2.shape
# Out:
# (8399, 16)

# %%
### 3
df3=pd.merge(df2,ship_df,on='Ship_id')
df3
# Out:
#         Ord_id  Prod_id   Ship_id    Cust_id     Sales  Discount  \
# 0     Ord_5446  Prod_16  SHP_7609  Cust_1818    136.81      0.01
# 1     Ord_2978  Prod_16  SHP_4112  Cust_1088    305.05      0.04
# 2     Ord_5484  Prod_16  SHP_7663  Cust_1820    322.82      0.05
# 3     Ord_3730  Prod_16  SHP_5175  Cust_1314    459.08      0.04
# 4     Ord_4143  Prod_16  SHP_5771  Cust_1417    207.21      0.06
# 5     Ord_4796  Prod_16  SHP_6686  Cust_1659     95.09      0.09
# 6     Ord_4796   Prod_6  SHP_6686  Cust_1659    122.09      0.04
# 7     Ord_1854  Prod_16  SHP_2548   Cust_727    182.47      0.05
# 8     Ord_1854   Prod_6  SHP_2548   Cust_622    817.53      0.03
# 9     Ord_1854  Prod_17  SHP_2548   Cust_564     25.96      0.06
# 10    Ord_4506  Prod_16  SHP_6273  Cust_1544     92.02      0.07
# 11    Ord_4080  Prod_16  SHP_5688  Cust_1388    666.40      0.00
# 12    Ord_1551  Prod_16  SHP_2145   Cust_531    184.77      0.00
# ...

# %%
### 4
master_id=pd.merge(df3,order_df,on='Ord_id')
master_id.shape
# Out:
# (8399, 22)

# %%
master_df.Product_Category.value_counts()
# Out:
# OFFICE SUPPLIES    4610
# TECHNOLOGY         2065
# FURNITURE          1724
# Name: Product_Category, dtype: int64

# %%
master_df.groupby('Product_Category').Sales.max()
# Out:
# Product_Category
# FURNITURE          29345.27
# OFFICE SUPPLIES    25409.63
# TECHNOLOGY         89061.05
# Name: Sales, dtype: float64

# %%
master_df.groupby('Product_Category').Sales.max().max()
# Out:
# 89061.05

# %%
cust_df.columns
# Out:
# Index(['Customer_Name', 'Province', 'Region', 'Customer_Segment', 'Cust_id'], dtype='object')

# %%
master_df.groupby('Customer_Segment').Sales.max().max()
# Out:
# 89061.05

# %%
master_df.groupby(['Customer_Segment','Product_Category']).Sales.max()
# Out:
# Customer_Segment  Product_Category
# CONSUMER          FURNITURE           28389.14
#                   OFFICE SUPPLIES     23516.31
#                   TECHNOLOGY          89061.05
# CORPORATE         FURNITURE           29345.27
#                   OFFICE SUPPLIES     23106.46
#                   TECHNOLOGY          41343.21
# HOME OFFICE       FURNITURE           28180.08
#                   OFFICE SUPPLIES     18697.24
#                   TECHNOLOGY          45923.76
# SMALL BUSINESS    FURNITURE           24639.80
#                   OFFICE SUPPLIES     25409.63
#                   TECHNOLOGY          33367.85
# Name: Sales, dtype: float64

# %%
master_df.groupby('Customer_Segment').Sales.mean().mean()
# Out:
# 1774.4945315234252

# %%
master_df[master_df.Product_Category=='FURNITURE'].Sales.max()
# Out:
# 29345.27

# %% [markdown]
# ### pandas 101
# ### numpy 100
# ### python 100

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
sns.boxplot(x=master_df['Product_Category'],\
            y=master_df['Sales'])

# %%
sns.boxplot(x=master_df['Product_Category'],\
            y=master_df['Profit'])

# %%
sns.jointplot(master_df['Profit'],master_df['Sales'])
